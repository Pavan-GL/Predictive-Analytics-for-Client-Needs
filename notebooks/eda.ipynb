# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('D:\Predictive Analytics for Client Needs\data\client_interactions.csv')
data.head()
# Out:
#    client_id                                               text  \
# 0          1  The client is looking for advice on tax optimi...
# 1          2        They need assistance with audit compliance.
# 2          3    Request for a financial risk assessment report.
# 3          4  The client wants to explore investment opportu...
# 4          5  They have queries regarding their financial st...
#
#                 labels
# 0         Tax Advisory
# 1                Audit
# 2      Risk Assessment
# 3  Investment Advisory
# 4  Financial Reporting

# %%
data.shape
# Out:
# (10, 3)

# %%
data.isnull().sum()
# Out:
# client_id    0
# text         0
# labels       0
# dtype: int64

# %%
data.describe()
# Out:
#        client_id
# count   10.00000
# mean     5.50000
# std      3.02765
# min      1.00000
# 25%      3.25000
# 50%      5.50000
# 75%      7.75000
# max     10.00000

# %%
data.dtypes
# Out:
# client_id     int64
# text         object
# labels       object
# dtype: object

# %%
if 'labels' in data.columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x='labels', data=data)
    plt.title('Distribution of Target Labels')
    plt.xlabel('Labels')
    plt.ylabel('Count')
    plt.show()

# %%
# Visualize correlations (if applicable)
if 'labels' in data.columns:
    plt.figure(figsize=(12, 8))
    correlation_matrix = data.corr()
    sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
    plt.title('Correlation Matrix')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       2 if 'labels' in data.columns:
#       3     plt.figure(figsize=(12, 8))
# ----> 4     correlation_matrix = data.corr()
#       5     sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
#       6     plt.title('Correlation Matrix')
#
# File d:\Predictive Analytics for Client Needs\venv\lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File d:\Predictive Analytics for Client Needs\venv\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...

# %%
# Check for duplicate records
duplicates = data.duplicated().sum()
print(f"Number of duplicate records: {duplicates}")

# Analyze text column (assuming there is a 'text' column)
if 'text' in data.columns:
    print("Sample text data:")
    print(data['text'].sample(5, random_state=1))

    # Length of text data
    data['text_length'] = data['text'].apply(len)

    plt.figure(figsize=(10, 6))
    sns.histplot(data['text_length'], bins=30, kde=True)
    plt.title('Distribution of Text Length')
    plt.xlabel('Text Length')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Number of duplicate records: 0
# Sample text data:
# 2      Request for a financial risk assessment report.
# 9    The client is interested in estate planning se...
# 6    The client seeks guidance on international tax...
# 4    They have queries regarding their financial st...
# 0    The client is looking for advice on tax optimi...
# Name: text, dtype: object

# %%
# Visualizing word clouds for text analysis (optional)
from wordcloud import WordCloud

if 'text' in data.columns:
    all_words = ' '.join(data['text'].dropna())
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_words)

    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Text Data')
    plt.show()
